# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
alcohol_data = pd.read_excel('Alcohol Data.xlsx')
alcohol_data.head(50)
# Out:
#     Year             WHO region  \
# 0   1986        Western Pacific
# 1   1986               Americas
# 2   1985                 Africa
# 3   1986               Americas
# 4   1987               Americas
# 5   1987               Americas
# 6   1987                 Africa
# 7   1985                 Africa
# 8   1986               Americas
# 9   1984                 Africa
# 10  1987                 Africa
# 11  1989               Americas
# 12  1985        Western Pacific
# 13  1984  Eastern Mediterranean
# 14  1985        Western Pacific
# 15  1987                 Africa
# 16  1984               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 20  1986        South-East Asia
# 21  1989               Americas
# 22  1984                 Europe
# 23  1984                 Europe
# 24  1985                 Africa
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# ...

# %%
alcohol_data.shape
# Out:
# (100, 5)

# %%
alcohol_data.columns
# Out:
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %%
alcohol_data.Year
# Out:
# 0     1986
# 1     1986
# 2     1985
# 3     1986
# 4     1987
#       ...
# 95    1984
# 96    1985
# 97    1984
# 98    1984
# 99    1985
# Name: Year, Length: 100, dtype: int64

# %%
alcohol_data['Year']
# Out:
# 0     1986
# 1     1986
# 2     1985
# 3     1986
# 4     1987
#       ...
# 95    1984
# 96    1985
# 97    1984
# 98    1984
# 99    1985
# Name: Year, Length: 100, dtype: int64

# %%
alcohol_data.head(2)
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5

# %%
alcohol_data.iloc[0:2, 0:2]
# Out:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas

# %%
alcohol_data[['Year', 'WHO region']]
# Out:
#     Year       WHO region
# 0   1986  Western Pacific
# 1   1986         Americas
# 2   1985           Africa
# 3   1986         Americas
# 4   1987         Americas
# ..   ...              ...
# 95  1984           Africa
# 96  1985           Europe
# 97  1984  South-East Asia
# 98  1984           Africa
# 99  1985  South-East Asia
#
# [100 rows x 2 columns]

# %%
#to get random data you use the sample method 
alcohol_data.sample(10)
# Out:
#     Year             WHO region                Country Beverage Types  \
# 58  1984  Eastern Mediterranean                Somalia        Spirits
# 70  1986                 Africa             Madagascar        Spirits
# 42  1984                 Europe                Ukraine        Spirits
# 48  1987               Americas              Nicaragua           Beer
# 55  1989               Americas               Suriname           Wine
# 47  1986               Americas                 Mexico          Other
# 38  1987  Eastern Mediterranean                  Qatar          Other
# 35  1985               Americas  Saint Kitts and Nevis        Spirits
# 23  1984                 Europe                 Turkey           Beer
# 15  1987                 Africa          Guinea-Bissau           Wine
#
#     Display Value
# 58           0.00
# 70           1.02
# 42           3.06
# 48           0.70
# 55           0.04
# 47           0.04
# 38           0.00
# 35           2.24
# 23           0.44
# ...

# %%
#to get the fraction of the random rows, use frac, a parameter inside the sample
alcohol_data.sample(frac=0.3)
# Out:
#     Year             WHO region                                Country  \
# 48  1987               Americas                              Nicaragua
# 12  1985        Western Pacific       Lao People's Democratic Republic
# 67  1989                 Africa                                Namibia
# 78  1989               Americas                                Jamaica
# 89  1986  Eastern Mediterranean                                Lebanon
# 47  1986               Americas                                 Mexico
# 25  1984  Eastern Mediterranean                                Tunisia
# 68  1989                 Africa                                 Uganda
# 53  1984  Eastern Mediterranean                                 Kuwait
# 7   1985                 Africa                                 Angola
# 99  1985        South-East Asia  Democratic People's Republic of Korea
# 90  1989                 Africa                                 Malawi
# ...

# %%
alcohol_data.isnull().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64

# %%
alcohol_data.dropna(inplace=True)

# %%
alcohol_data
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
#check the unique values in the WHO region

alcohol_data['WHO region'].unique()
# Out:
# array(['Western Pacific', 'Americas', 'Africa', 'Eastern Mediterranean',
#        'Europe', 'South-East Asia'], dtype=object)

# %%
#drop the duplicates using the drop_duplicates and keep parameter 
alcohol_data['WHO region'].drop_duplicates(keep='first')
# Out:
# 0           Western Pacific
# 1                  Americas
# 2                    Africa
# 13    Eastern Mediterranean
# 18                   Europe
# 20          South-East Asia
# Name: WHO region, dtype: object

# %%
alcohol_data[alcohol_data['Year'] == 1987]
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 4   1987               Americas       Saint Kitts and Nevis           Beer
# 5   1987               Americas                   Guatemala          Other
# 6   1987                 Africa                   Mauritius           Wine
# 10  1987                 Africa                    Botswana           Wine
# 15  1987                 Africa               Guinea-Bissau           Wine
# 28  1987        Western Pacific                    Viet Nam           Beer
# 36  1987  Eastern Mediterranean                       Egypt           Beer
# 38  1987  Eastern Mediterranean                       Qatar          Other
# 39  1987                 Africa                Burkina Faso        Spirits
# 40  1987                 Europe                     Austria        Spirits
# 46  1987               Americas         Trinidad and Tobago        Spirits
# ...

# %%
alcohol_data[(alcohol_data['Year'] == 1987) | (alcohol_data['Year'] == 1989)]
# Out:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# 39  1987                 Africa                      Burkina Faso
# ...

# %%
alcohol_data[(alcohol_data['WHO region'] == 'Americas') & (alcohol_data['Year'] == 1985)]
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 35  1985   Americas  Saint Kitts and Nevis        Spirits           2.24

# %%
alcohol_data[(alcohol_data['Year'] == 1986) & (alcohol_data['WHO region'] =='Western Pacific') & (alcohol_data['Country'] =="Viet Nam")]
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0

# %%
alcohol_data[(alcohol_data['WHO region'] == 'Americas') & (alcohol_data['Year'].isin([1986, 1989]))]
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 47  1986   Americas                            Mexico          Other
# 55  1989   Americas                          Suriname           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# 74  1986   Americas  Bolivia (Plurinational State of)        Spirits
# 78  1989   Americas                           Jamaica          Other
# 86  1986   Americas                           Bahamas           Wine
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 11           0.62
# 21           4.51
# 47           0.04
# ...

# %%
#fig, ax = plt.subplots()
alcohol_data.head(10).plot.bar(x='WHO region', y='Display Value', color=['red', 'blue', 'indigo', 'violet', 
                                                       'magenta'])
                             
# ax.set_xlabel('The Regions')
# ax.set_ylabel('The Years')
# ax.set_title('The Regions over the years')
# plt.show()
# Out:
# <Axes: xlabel='WHO region'>
